# %%
# %pip install
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ERROR: You must give at least one requirement to install (see "pip help install")

# %%
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize, sent_tokenize
import heapq

# %%
nltk.download('punkt')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\harin\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\harin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
text="""
Artifical intelligence (AI) is a branch of computer science that aims to create intelligent machines.It has applications in various fields such as healthcare, finance, education, and automous vechicles.Machine learning , a subset of AI , allows systems to learn from from data without explicit programming.Natural Language Processing enables machines to understand and interpret human language.AI continues to grow rapidly and impacts everyday life in multiple ways"""

# %%
stop_words=set(stopwords.words("english"))
words=word_tokenize(text.lower())
word_frequencies={}

for word in words:
    if word not in stop_words and word.isalpha():
        word_frequencies[word]=word_frequencies.get(word, 0)+1

sentences=sent_tokenize(text)
sentence_scores={}
for sent in sentences:
    for word in word_tokenize(sent.lower()):
        if word in word_frequencies:
            sentence_scores[sent]=sentence_scores.get(sent, 0)+ word_frequencies[word]

summary_sentences=heapq.nlargest(3, sentence_scores, key=sentence_scores.get)
summary=" ".join(summary_sentences)
print("Summary:\n", summary)
# Out:
# Summary:
#
# Artifical intelligence (AI) is a branch of computer science that aims to create intelligent machines.It has applications in various fields such as healthcare, finance, education, and automous vechicles.Machine learning , a subset of AI , allows systems to learn from from data without explicit programming.Natural Language Processing enables machines to understand and interpret human language.AI continues to grow rapidly and impacts everyday life in multiple ways
